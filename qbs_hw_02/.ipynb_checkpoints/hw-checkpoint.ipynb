# %%
import pandas as pd

train_data = pd.read_csv('train.csv') 
test_data = pd.read_csv('test.csv')

# %%
train_data
# Out:
#           ID  Age          Workclass  fnlwgt      Education  Education_Num  \
# 0          2   38            Private   89814        HS-grad              9
# 1          5   18                NaN  103497   Some-college             10
# 2          6   34            Private  198693           10th              6
# 3          7   29                NaN  227026        HS-grad              9
# 4         10   55            Private  104996        7th-8th              4
# ...      ...  ...                ...     ...            ...            ...
# 29509  48832   43   Self-emp-not-inc   27242   Some-college             10
# 29510  48833   32            Private   34066           10th              6
# 29511  48834   43            Private   84661      Assoc-voc             11
# 29512  48838   27            Private  257302     Assoc-acdm             12
# 29513  48841   22            Private  201490        HS-grad              9
#
#             Martial_Status          Occupation    Relationship  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

age_for_NaN = train_data.Age.median()
##print(age_for_NaN)

def fill_in_null(column, replace_item):
    for (i, item) in enumerate( column.isnull() ):
        if(item == True):
            column[i] = replace_item

def is_null(column):
    for (i, item) in enumerate( column.isnull() ):
        if(item == True):
            print("NaN")

# %%
is_null(train_data.Age)
is_null(train_data.fnlwgt)

print(train_data.Age.dtypes)
train_data.fnlwgt = train_data.fnlwgt.astype("float64")
print(train_data.fnlwgt)
# Out:
# int64
# 0         89814.0
# 1        103497.0
# 2        198693.0
# 3        227026.0
# 4        104996.0
#            ...
# 29509     27242.0
# 29510     34066.0
# 29511     84661.0
# 29512    257302.0
# 29513    201490.0
# Name: fnlwgt, Length: 29514, dtype: float64

# %%
def normalise(column):
    mean_value = column.mean()
    std_value = column.std()
    for i in range(len(column)):
        column[i] = (column[i]  - mean_value) / std_value

normalise(train_data.fnlwgt)
train_data.fnlwgt = train_data.fnlwgt.round(decimals=2)
print(train_data.fnlwgt)
# Out:
# /Users/fciixgear/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 0       -0.94
# 1       -0.81
# 2        0.08
# 3        0.35
# 4       -0.80
#          ...
# 29509   -1.53
# 29510   -1.47
# 29511   -0.99
# 29512    0.63
# 29513    0.11
# Name: fnlwgt, Length: 29514, dtype: float64

# %%
f, axes = plt.subplots(1,6, figsize=(40, 7))
age_pic = sns.distplot(train_data.Age, ax=axes[0])
workclass_pic = sns.countplot(train_data.Workclass, ax=axes[1])

#fnlwgt_vs_target = sns.barplot(x='fnlwgt', y='Target', data=train_data, ax=axes[2])
age_vs_target = sns.barplot(x='Age', y='Target',data=train_data, ax=axes[3])
workclass_vs_target = sns.barplot(x='Workclass', y='Target',data=train_data, ax=axes[4])

# %%
train_data = train_data.drop(columns="fnlwgt")
print(train_data)
# Out:
#           ID  Age          Workclass      Education  Education_Num  \
# 0          2   38            Private        HS-grad              9
# 1          5   18                NaN   Some-college             10
# 2          6   34            Private           10th              6
# 3          7   29                NaN        HS-grad              9
# 4         10   55            Private        7th-8th              4
# ...      ...  ...                ...            ...            ...
# 29509  48832   43   Self-emp-not-inc   Some-college             10
# 29510  48833   32            Private           10th              6
# 29511  48834   43            Private      Assoc-voc             11
# 29512  48838   27            Private     Assoc-acdm             12
# 29513  48841   22            Private        HS-grad              9
#
#             Martial_Status          Occupation    Relationship  \
# 0       Married-civ-spouse     Farming-fishing         Husband
# ...

# %%
is_null(train_data.Workclass)
filli
# Out:
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# NaN
# ...
